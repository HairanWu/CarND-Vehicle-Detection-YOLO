# %% [markdown]
# # Vehicle Detection Project
#
# This sub project converts yolo model to keras.

# %% [markdown]
# ## Import Packages

# %%
import argparse
import configparser
import io
import os
from collections import defaultdict
import colorsys
import random
import matplotlib.image as mpimg
import cv2
import numpy as np

from keras import backend as K
from keras.layers import (Conv2D, GlobalAveragePooling2D, Input, Lambda,
                          MaxPooling2D,Add,UpSampling2D,Concatenate)
from keras.layers import (Conv2D, GlobalAveragePooling2D, Input, Reshape,
                          UpSampling2D, Activation)
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.merge import concatenate
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.regularizers import l2
from keras.utils.vis_utils import plot_model as plot
from keras.models import load_model
from keras.layers.merge import concatenate, add


import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Global variables

# %% [markdown]
# yolov2 config file can get from https://github.com/pjreddie/darknet/blob/master/cfg/yolov2.cfg
#
# yolov2 wights file can get from https://pjreddie.com/media/files/yolov2.weights
#
# yolov3 config file can get from https://github.com/pjreddie/darknet/blob/master/cfg/yolov3.cfg
#
# yolov3 wights file can get from https://pjreddie.com/media/files/yolov3.weights

# %%
#yolov2
# config_path = 'yolov2.cfg'
# weights_path = 'yolov2.weights'

#yolov3
config_path = 'yolov3.cfg'
weights_path = 'yolov3.weights'
anchors_path='model_data/yolov3_anchors.txt'

classes_path='model_data/coco_classes.txt'
# anchors_path='model_data/yolo_anchors.txt'
output_root = 'model_data/yolo.h5'

# %% [markdown]
# ## Cfg File Parse

# %%
def unique_config_sections(config_file):
    """Convert all config sections to have unique names.

    Adds unique suffixes to config sections for compability with configparser.
    """
    section_counters = defaultdict(int)
    output_stream = io.StringIO()
    with open(config_file) as fin:
        for line in fin:
            if line.startswith('['):
                section = line.strip().strip('[]')
                _section = section + '_' + str(section_counters[section])
                section_counters[section] += 1
                line = line.replace(section, _section)
            output_stream.write(line)
    output_stream.seek(0)
    return output_stream

# %%
print('Parsing Darknet config.')
unique_config_file = unique_config_sections(config_path)
cfg_parser = configparser.ConfigParser()
cfg_parser.read_file(unique_config_file)

print(cfg_parser.sections())
# Out:
# Parsing Darknet config.
# ['net_0', 'convolutional_0', 'convolutional_1', 'convolutional_2', 'convolutional_3', 'shortcut_0', 'convolutional_4', 'convolutional_5', 'convolutional_6', 'shortcut_1', 'convolutional_7', 'convolutional_8', 'shortcut_2', 'convolutional_9', 'convolutional_10', 'convolutional_11', 'shortcut_3', 'convolutional_12', 'convolutional_13', 'shortcut_4', 'convolutional_14', 'convolutional_15', 'shortcut_5', 'convolutional_16', 'convolutional_17', 'shortcut_6', 'convolutional_18', 'convolutional_19', 'shortcut_7', 'convolutional_20', 'convolutional_21', 'shortcut_8', 'convolutional_22', 'convolutional_23', 'shortcut_9', 'convolutional_24', 'convolutional_25', 'shortcut_10', 'convolutional_26', 'convolutional_27', 'convolutional_28', 'shortcut_11', 'convolutional_29', 'convolutional_30', 'shortcut_12', 'convolutional_31', 'convolutional_32', 'shortcut_13', 'convolutional_33', 'convolutional_34', 'shortcut_14', 'convolutional_35', 'convolutional_36', 'shortcut_15', 'convolutional_37', 'convolutional_38', 'shortcut_16', 'convolutional_39', 'convolutional_40', 'shortcut_17', 'convolutional_41', 'convolutional_42', 'shortcut_18', 'convolutional_43', 'convolutional_44', 'convolutional_45', 'shortcut_19', 'convolutional_46', 'convolutional_47', 'shortcut_20', 'convolutional_48', 'convolutional_49', 'shortcut_21', 'convolutional_50', 'convolutional_51', 'shortcut_22', 'convolutional_52', 'convolutional_53', 'convolutional_54', 'convolutional_55', 'convolutional_56', 'convolutional_57', 'convolutional_58', 'yolo_0', 'route_0', 'convolutional_59', 'upsample_0', 'route_1', 'convolutional_60', 'convolutional_61', 'convolutional_62', 'convolutional_63', 'convolutional_64', 'convolutional_65', 'convolutional_66', 'yolo_1', 'route_2', 'convolutional_67', 'upsample_1', 'route_3', 'convolutional_68', 'convolutional_69', 'convolutional_70', 'convolutional_71', 'convolutional_72', 'convolutional_73', 'convolutional_74', 'yolo_2']

# %% [markdown]
# # weights

# %%
# Load weights and config.
print('Loading weights.')
weights_file = open(weights_path, 'rb')
weights_header = np.ndarray(
    shape=(5, ), dtype='int32', buffer=weights_file.read(20))
print('Weights Header: ', weights_header)
weights_file.close()
# Out:
# Loading weights.
# Weights Header:  [       0        2        0 32013312        0]

# %% [markdown]
# # Construct the network

# %%
def space_to_depth_x2(x):
    """Thin wrapper for Tensorflow space_to_depth with block_size=2."""
    # Import currently required to make Lambda work.
    # See: https://github.com/fchollet/keras/issues/5088#issuecomment-273851273
    import tensorflow as tf
    return tf.space_to_depth(x, block_size=2)


def space_to_depth_x2_output_shape(input_shape):
    """Determine space_to_depth output shape for block_size=2.

    Note: For Lambda with TensorFlow backend, output shape may not be needed.
    """
    return (input_shape[0], input_shape[1] // 2, input_shape[2] // 2, 4 *
            input_shape[3]) if input_shape[1] else (input_shape[0], None, None,
                                                    4 * input_shape[3])

# %%
print('Creating Keras model.')
weights_file = open(weights_path, 'rb')
weights_header = np.ndarray(
    shape=(5, ), dtype='int32', buffer=weights_file.read(20))
print('Weights Header: ', weights_header)

image_height = int(cfg_parser['net_0']['height'])
image_width = int(cfg_parser['net_0']['width'])

# prev_layer = Input(shape=(image_height, image_width, 3))
# all_layers = [prev_layer]

input_layer = Input(shape=(image_height, image_width, 3))
prev_layer = input_layer
all_layers = []

weight_decay = float(cfg_parser['net_0']['decay']) if 'net_0' in cfg_parser.sections() else 5e-4

count = 0
out_index = []
    
for section in cfg_parser.sections():
    print('Parsing section {}'.format(section))
    if section.startswith('convolutional'):
#         [convolutional]
#         batch_normalize=1
#         filters=32
#         size=3
#         stride=1
#         pad=1
#         activation=leaky
        batch_normalize = 'batch_normalize' in cfg_parser[section]
        filters = int(cfg_parser[section]['filters'])
        size = int(cfg_parser[section]['size'])
        stride = int(cfg_parser[section]['stride'])
        pad = int(cfg_parser[section]['pad'])
        activation = cfg_parser[section]['activation']
        
        # padding='same' is equivalent to Darknet pad=1
        padding = 'same' if pad == 1 else 'valid'

        # Setting weights.
        # Darknet serializes convolutional weights as:
        # [bias/beta, [gamma, mean, variance], conv_weights]
        prev_layer_shape = K.int_shape(prev_layer)

        # TODO: This assumes channel last dim_ordering.
        weights_shape = (size, size, prev_layer_shape[-1], filters)
        darknet_w_shape = (filters, weights_shape[2], size, size)
        weights_size = np.product(weights_shape)

#         print('conv2d', 'bn'
#               if batch_normalize else '  ', activation, weights_shape)

        conv_bias = np.ndarray(shape=(filters, ),dtype='float32',buffer=weights_file.read(filters * 4))
        count += filters

        if batch_normalize:
            bn_weights = np.ndarray(shape=(3, filters),dtype='float32',buffer=weights_file.read(filters * 12))
            count += 3 * filters

            # TODO: Keras BatchNormalization mistakenly refers to var
            # as std.
            bn_weight_list = [
                bn_weights[0],  # scale gamma
                conv_bias,  # shift beta
                bn_weights[1],  # running mean
                bn_weights[2]  # running var
            ]

        conv_weights = np.ndarray(shape=darknet_w_shape,dtype='float32',buffer=weights_file.read(weights_size * 4))
        count += weights_size

        # DarkNet conv_weights are serialized Caffe-style:
        # (out_dim, in_dim, height, width)
        # We would like to set these to Tensorflow order:
        # (height, width, in_dim, out_dim)
        # TODO: Add check for Theano dim ordering.
        conv_weights = np.transpose(conv_weights, [2, 3, 1, 0])
        conv_weights = [conv_weights] if batch_normalize else [conv_weights, conv_bias]

        # Handle activation.
        act_fn = None
        if activation == 'leaky':
            pass  # Add advanced activation later.
        elif activation != 'linear':
            raise ValueError(
                'Unknown activation function `{}` in section {}'.format(
                    activation, section))

        # Create Conv2D layer
        conv_layer = (Conv2D(filters, (size, size),strides=(stride, stride),kernel_regularizer=l2(weight_decay),\
            use_bias=not batch_normalize,weights=conv_weights,activation=act_fn,padding=padding))(prev_layer)

        if batch_normalize:
            conv_layer = (BatchNormalization(weights=bn_weight_list))(conv_layer)
        prev_layer = conv_layer

        if activation == 'linear':
            all_layers.append(prev_layer)
        elif activation == 'leaky':
            act_layer = LeakyReLU(alpha=0.1)(prev_layer)
            prev_layer = act_layer
            all_layers.append(act_layer)

    elif section.startswith('maxpool'):
#         [maxpool]
#         size=2
#         stride=2
        size = int(cfg_parser[section]['size'])
        stride = int(cfg_parser[section]['stride'])
        all_layers.append(MaxPooling2D(padding='same',pool_size=(size, size),strides=(stride, stride))(prev_layer))
        prev_layer = all_layers[-1]

    elif section.startswith('avgpool'):
        if cfg_parser.items(section) != []:
            raise ValueError('{} with params unsupported.'.format(section))
        all_layers.append(GlobalAveragePooling2D()(prev_layer))
        prev_layer = all_layers[-1]

    elif section.startswith('route'):
#         [route]
#         layers=-9
        ids = [int(i) for i in cfg_parser[section]['layers'].split(',')]
        layers = [all_layers[i] for i in ids]
        if len(layers) > 1:
            print('Concatenating route layers:', layers)
            concatenate_layer = concatenate(layers)
            all_layers.append(concatenate_layer)
            prev_layer = concatenate_layer
        else:
            skip_layer = layers[0]  # only one layer to route
            all_layers.append(skip_layer)
            prev_layer = skip_layer

    elif section.startswith('reorg'):
        block_size = int(cfg_parser[section]['stride'])
        assert block_size == 2, 'Only reorg with stride 2 supported.'
        all_layers.append(
            Lambda(space_to_depth_x2,output_shape=space_to_depth_x2_output_shape,name='space_to_depth_x2')(prev_layer))
        prev_layer = all_layers[-1]

    elif section.startswith('region'):
        with open('{}_anchors.txt'.format(output_root), 'w') as f:
            print(cfg_parser[section]['anchors'], file=f)
        
    elif section.startswith('shortcut'):
        index = int(cfg_parser[section]['from'])
        activation = cfg_parser[section]['activation']
        assert activation == 'linear', 'Only linear activation supported.'
        all_layers.append(Add()([all_layers[index], prev_layer]))
        prev_layer = all_layers[-1]
        
    elif section.startswith('upsample'):
        stride = int(cfg_parser[section]['stride'])
        assert stride == 2, 'Only stride=2 supported.'
        all_layers.append(UpSampling2D(stride)(prev_layer))
        prev_layer = all_layers[-1]

    # TODO: Further implement needed.
    elif section.startswith('yolo'):
        out_index.append(len(all_layers)-1)
        all_layers.append(None)
        prev_layer = all_layers[-1]

    elif (section.startswith('net') or section.startswith('cost') or
          section.startswith('softmax')):
        pass  # Configs not currently handled during model definition.

    else:
        raise ValueError(
            'Unsupported section header type: {}'.format(section))

# Create and save model.
# model = Model(inputs=all_layers[0], outputs=all_layers[-1])
model = Model(inputs=input_layer, outputs=[all_layers[i] for i in out_index])
model.save('{}'.format(output_root))
print('Saved Keras model to {}'.format(output_root))
# Check to see if all weights have been read.
remaining_weights = len(weights_file.read()) / 4
weights_file.close()
print('Read {} of {} from Darknet weights.'.format(count, count + remaining_weights))

print("Construction Done!")
# Out:
# Creating Keras model.
# Weights Header:  [       0        2        0 32013312        0]
# Parsing section net_0
# Parsing section convolutional_0
# Parsing section convolutional_1
# Parsing section convolutional_2
# Parsing section convolutional_3
# Parsing section shortcut_0
# Parsing section convolutional_4
# Parsing section convolutional_5
# Parsing section convolutional_6
# Parsing section shortcut_1
# Parsing section convolutional_7
# Parsing section convolutional_8
# Parsing section shortcut_2
# Parsing section convolutional_9
# Parsing section convolutional_10
# Parsing section convolutional_11
# Parsing section shortcut_3
# Parsing section convolutional_12
# Parsing section convolutional_13
# Parsing section shortcut_4
# Parsing section convolutional_14
# Parsing section convolutional_15
# Parsing section shortcut_5
# Parsing section convolutional_16
# Parsing section convolutional_17
# Parsing section shortcut_6
# Parsing section convolutional_18
# Parsing section convolutional_19
# Parsing section shortcut_7
# Parsing section convolutional_20
# Parsing section convolutional_21
# Parsing section shortcut_8
# Parsing section convolutional_22
# Parsing section convolutional_23
# Parsing section shortcut_9
# Parsing section convolutional_24
# Parsing section convolutional_25
# Parsing section shortcut_10
# Parsing section convolutional_26
# Parsing section convolutional_27
# Parsing section convolutional_28
# Parsing section shortcut_11
# Parsing section convolutional_29
# Parsing section convolutional_30
# Parsing section shortcut_12
# Parsing section convolutional_31
# Parsing section convolutional_32
# Parsing section shortcut_13
# Parsing section convolutional_33
# Parsing section convolutional_34
# Parsing section shortcut_14
# Parsing section convolutional_35
# Parsing section convolutional_36
# Parsing section shortcut_15
# Parsing section convolutional_37
# Parsing section convolutional_38
# Parsing section shortcut_16
# Parsing section convolutional_39
# Parsing section convolutional_40
# Parsing section shortcut_17
# Parsing section convolutional_41
# Parsing section convolutional_42
# Parsing section shortcut_18
# Parsing section convolutional_43
# Parsing section convolutional_44
# Parsing section convolutional_45
# Parsing section shortcut_19
# Parsing section convolutional_46
# Parsing section convolutional_47
# Parsing section shortcut_20
# Parsing section convolutional_48
# Parsing section convolutional_49
# Parsing section shortcut_21
# Parsing section convolutional_50
# Parsing section convolutional_51
# Parsing section shortcut_22
# Parsing section convolutional_52
# Parsing section convolutional_53
# Parsing section convolutional_54
# Parsing section convolutional_55
# Parsing section convolutional_56
# Parsing section convolutional_57
# Parsing section convolutional_58
# Parsing section yolo_0
# Parsing section route_0
# Parsing section convolutional_59
# Parsing section upsample_0
# Parsing section route_1
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_3/ResizeNearestNeighbor:0' shape=(?, 26, 26, 256) dtype=float32>, <tf.Tensor 'add_42/add:0' shape=(?, 26, 26, 512) dtype=float32>]
# Parsing section convolutional_60
# Parsing section convolutional_61
# Parsing section convolutional_62
# Parsing section convolutional_63
# Parsing section convolutional_64
# Parsing section convolutional_65
# Parsing section convolutional_66
# Parsing section yolo_1
# Parsing section route_2
# Parsing section convolutional_67
# Parsing section upsample_1
# Parsing section route_3
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_4/ResizeNearestNeighbor:0' shape=(?, 52, 52, 128) dtype=float32>, <tf.Tensor 'add_34/add:0' shape=(?, 52, 52, 256) dtype=float32>]
# Parsing section convolutional_68
# Parsing section convolutional_69
# Parsing section convolutional_70
# Parsing section convolutional_71
# Parsing section convolutional_72
# Parsing section convolutional_73
# Parsing section convolutional_74
# Parsing section yolo_2
# Saved Keras model to model_data/yolo.h5
# Read 62001757 of 62001757.0 from Darknet weights.
# Construction Done!

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 416, 416, 3)  0
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 416, 416, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 416, 416, 32) 128         conv2d_76[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 416, 416, 32) 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 208, 208, 64) 18432       leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 208, 208, 64) 256         conv2d_77[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 208, 208, 64) 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 208, 208, 32) 2048        leaky_re_lu_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 208, 208, 32) 128         conv2d_78[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, 208, 208, 32) 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 208, 208, 64) 18432       leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 208, 208, 64) 256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)      (None, 208, 208, 64) 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 208, 208, 64) 0           leaky_re_lu_74[0][0]
#                                                                  leaky_re_lu_76[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 104, 104, 128 73728       add_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 104, 104, 128 512         conv2d_80[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)      (None, 104, 104, 128 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 104, 104, 64) 8192        leaky_re_lu_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 104, 104, 64) 256         conv2d_81[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)      (None, 104, 104, 64) 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 104, 104, 128 73728       leaky_re_lu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 104, 104, 128 512         conv2d_82[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)      (None, 104, 104, 128 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 104, 104, 128 0           leaky_re_lu_77[0][0]
#                                                                  leaky_re_lu_79[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 104, 104, 64) 8192        add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 104, 104, 64) 256         conv2d_83[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)      (None, 104, 104, 64) 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 104, 104, 128 73728       leaky_re_lu_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 104, 104, 128 512         conv2d_84[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)      (None, 104, 104, 128 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 104, 104, 128 0           add_25[0][0]
#                                                                  leaky_re_lu_81[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 52, 52, 256)  294912      add_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 52, 52, 256)  1024        conv2d_85[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 52, 52, 128)  32768       leaky_re_lu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 52, 52, 128)  512         conv2d_86[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 52, 52, 256)  294912      leaky_re_lu_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 52, 52, 256)  1024        conv2d_87[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 52, 52, 256)  0           leaky_re_lu_82[0][0]
#                                                                  leaky_re_lu_84[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 52, 52, 128)  32768       add_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 52, 52, 128)  512         conv2d_88[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_85 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 52, 52, 256)  294912      leaky_re_lu_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 52, 52, 256)  1024        conv2d_89[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_86 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 52, 52, 256)  0           add_27[0][0]
#                                                                  leaky_re_lu_86[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 52, 52, 128)  32768       add_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 52, 52, 128)  512         conv2d_90[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_87 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 52, 52, 256)  294912      leaky_re_lu_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 52, 52, 256)  1024        conv2d_91[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_88 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 52, 52, 256)  0           add_28[0][0]
#                                                                  leaky_re_lu_88[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 52, 52, 128)  32768       add_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 52, 52, 128)  512         conv2d_92[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_89 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 52, 52, 256)  294912      leaky_re_lu_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 52, 52, 256)  1024        conv2d_93[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_90 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 52, 52, 256)  0           add_29[0][0]
#                                                                  leaky_re_lu_90[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 52, 52, 128)  32768       add_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 52, 52, 128)  512         conv2d_94[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_91 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 52, 52, 256)  294912      leaky_re_lu_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 52, 52, 256)  1024        conv2d_95[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_92 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 52, 52, 256)  0           add_30[0][0]
#                                                                  leaky_re_lu_92[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 52, 52, 128)  32768       add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 52, 52, 128)  512         conv2d_96[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_93 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 52, 52, 256)  294912      leaky_re_lu_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 52, 52, 256)  1024        conv2d_97[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_94 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 52, 52, 256)  0           add_31[0][0]
#                                                                  leaky_re_lu_94[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 52, 52, 128)  32768       add_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 52, 52, 128)  512         conv2d_98[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_95 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 52, 52, 256)  294912      leaky_re_lu_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 52, 52, 256)  1024        conv2d_99[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_96 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 52, 52, 256)  0           add_32[0][0]
#                                                                  leaky_re_lu_96[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 52, 52, 128)  32768       add_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 52, 52, 128)  512         conv2d_100[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_97 (LeakyReLU)      (None, 52, 52, 128)  0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 52, 52, 256)  1024        conv2d_101[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_98 (LeakyReLU)      (None, 52, 52, 256)  0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 52, 52, 256)  0           add_33[0][0]
#                                                                  leaky_re_lu_98[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 26, 26, 512)  1179648     add_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 26, 26, 512)  2048        conv2d_102[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_99 (LeakyReLU)      (None, 26, 26, 512)  0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 26, 26, 256)  131072      leaky_re_lu_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 26, 26, 256)  1024        conv2d_103[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_100 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 26, 26, 512)  2048        conv2d_104[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_101 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 26, 26, 512)  0           leaky_re_lu_99[0][0]
#                                                                  leaky_re_lu_101[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 26, 26, 256)  131072      add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 26, 26, 256)  1024        conv2d_105[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_102 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 26, 26, 512)  2048        conv2d_106[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_103 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 26, 26, 512)  0           add_35[0][0]
#                                                                  leaky_re_lu_103[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 26, 26, 256)  131072      add_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 26, 26, 256)  1024        conv2d_107[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_104 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 26, 26, 512)  2048        conv2d_108[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_105 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 26, 26, 512)  0           add_36[0][0]
#                                                                  leaky_re_lu_105[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 26, 26, 256)  131072      add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 26, 26, 256)  1024        conv2d_109[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_106 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 26, 26, 512)  2048        conv2d_110[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_107 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 26, 26, 512)  0           add_37[0][0]
#                                                                  leaky_re_lu_107[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 26, 26, 256)  131072      add_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 26, 26, 256)  1024        conv2d_111[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_108 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 26, 26, 512)  2048        conv2d_112[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_109 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 26, 26, 512)  0           add_38[0][0]
#                                                                  leaky_re_lu_109[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 26, 26, 256)  131072      add_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 26, 26, 256)  1024        conv2d_113[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_110 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 26, 26, 512)  2048        conv2d_114[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_111 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 26, 26, 512)  0           add_39[0][0]
#                                                                  leaky_re_lu_111[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 26, 26, 256)  131072      add_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 26, 26, 256)  1024        conv2d_115[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_112 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 26, 26, 512)  2048        conv2d_116[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_113 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 26, 26, 512)  0           add_40[0][0]
#                                                                  leaky_re_lu_113[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 26, 26, 256)  131072      add_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 26, 26, 256)  1024        conv2d_117[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_114 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 26, 26, 512)  2048        conv2d_118[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_115 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 26, 26, 512)  0           add_41[0][0]
#                                                                  leaky_re_lu_115[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 13, 13, 1024) 4718592     add_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 13, 13, 1024) 4096        conv2d_119[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_116 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 13, 13, 512)  524288      leaky_re_lu_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 13, 13, 512)  2048        conv2d_120[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_117 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 13, 13, 1024) 4096        conv2d_121[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_118 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 13, 13, 1024) 0           leaky_re_lu_116[0][0]
#                                                                  leaky_re_lu_118[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 13, 13, 512)  524288      add_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 13, 13, 512)  2048        conv2d_122[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_119 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 13, 13, 1024) 4096        conv2d_123[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_120 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 13, 13, 1024) 0           add_43[0][0]
#                                                                  leaky_re_lu_120[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 13, 13, 512)  524288      add_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 13, 13, 512)  2048        conv2d_124[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_121 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 13, 13, 1024) 4096        conv2d_125[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_122 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 13, 13, 1024) 0           add_44[0][0]
#                                                                  leaky_re_lu_122[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 13, 13, 512)  524288      add_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 13, 13, 512)  2048        conv2d_126[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_123 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 13, 13, 1024) 4096        conv2d_127[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_124 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 13, 13, 1024) 0           add_45[0][0]
#                                                                  leaky_re_lu_124[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 13, 13, 512)  524288      add_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 13, 13, 512)  2048        conv2d_128[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_125 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 13, 13, 1024) 4096        conv2d_129[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_126 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 13, 13, 512)  524288      leaky_re_lu_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 13, 13, 512)  2048        conv2d_130[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_127 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 13, 13, 1024) 4096        conv2d_131[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_128 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 13, 13, 512)  524288      leaky_re_lu_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 13, 13, 512)  2048        conv2d_132[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_129 (LeakyReLU)     (None, 13, 13, 512)  0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 13, 13, 256)  131072      leaky_re_lu_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 13, 13, 256)  1024        conv2d_135[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_131 (LeakyReLU)     (None, 13, 13, 256)  0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 26, 26, 256)  0           leaky_re_lu_131[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 26, 26, 768)  0           up_sampling2d_3[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 26, 26, 256)  196608      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 26, 26, 256)  1024        conv2d_136[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_132 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 26, 26, 512)  2048        conv2d_137[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_133 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 26, 26, 256)  131072      leaky_re_lu_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 26, 26, 256)  1024        conv2d_138[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_134 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 26, 26, 512)  2048        conv2d_139[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_135 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 26, 26, 256)  131072      leaky_re_lu_135[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 26, 26, 256)  1024        conv2d_140[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_136 (LeakyReLU)     (None, 26, 26, 256)  0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 26, 26, 128)  32768       leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 26, 26, 128)  512         conv2d_143[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_138 (LeakyReLU)     (None, 26, 26, 128)  0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 52, 52, 128)  0           leaky_re_lu_138[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 52, 52, 384)  0           up_sampling2d_4[0][0]
#                                                                  add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 52, 52, 128)  49152       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 52, 52, 128)  512         conv2d_144[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_139 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 52, 52, 256)  1024        conv2d_145[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_140 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 52, 52, 128)  32768       leaky_re_lu_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 52, 52, 128)  512         conv2d_146[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_141 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 52, 52, 256)  1024        conv2d_147[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_142 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 52, 52, 128)  32768       leaky_re_lu_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 52, 52, 128)  512         conv2d_148[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_143 (LeakyReLU)     (None, 52, 52, 128)  0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 13, 13, 1024) 4718592     leaky_re_lu_129[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 26, 26, 512)  1179648     leaky_re_lu_136[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 52, 52, 256)  294912      leaky_re_lu_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 13, 13, 1024) 4096        conv2d_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 26, 26, 512)  2048        conv2d_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 52, 52, 256)  1024        conv2d_149[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_130 (LeakyReLU)     (None, 13, 13, 1024) 0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_137 (LeakyReLU)     (None, 26, 26, 512)  0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_144 (LeakyReLU)     (None, 52, 52, 256)  0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 13, 13, 255)  261375      leaky_re_lu_130[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 26, 26, 255)  130815      leaky_re_lu_137[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 52, 52, 255)  65535       leaky_re_lu_144[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# None
